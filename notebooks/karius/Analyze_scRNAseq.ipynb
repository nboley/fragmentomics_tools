# %%
install.packages("BiocManager")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
BiocManager::install("SummarizedExperiment")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.14 (BiocManager 1.30.22), R 4.1.3 (2022-03-10)
#
# Installing package(s) 'BiocVersion', 'SummarizedExperiment'
#
# also installing the dependencies ‘MatrixGenerics’, ‘GenomicRanges’, ‘DelayedArray’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Old packages: 'annotate', 'AnnotationDbi', 'askpass', 'BH', 'Biobase',
#   'BiocGenerics', 'BiocParallel', 'Biostrings', 'bit', 'blob', 'brio',
#   'cachem', 'callr', 'cli', 'colorspace', 'crayon', 'curl', 'DBI', 'desc',
#   'digest', 'edgeR', 'evaluate', 'fansi', 'fastmap', 'formatR', 'fs',
#   'genefilter', 'GenomeInfoDb', 'geometry', 'ggplot2', 'glue', 'gtable',
#   'htmltools', 'httr', 'IRanges', 'IRkernel', 'isoband', 'jsonlite',
# ...

# %%
library(SummarizedExperiment)
# Out:
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
# ...

# %%
df <- readRDS("/scratch/karius/reference/scRNA-Healthy-Hematopoiesis-191120.rds")

# %%
unique(colData(df)$BioClassification)
# Out:
#  [1] "05_CMP.LMPP"    "08_GMP.Neut"    "01_HSC"         "06_CLP.1"
#  [5] "15_CLP.2"       "02_Early.Eryth" "07_GMP"         "09_pDC"
#  [9] "04_Early.Baso"  "03_Late.Eryth"  "17_B"           "12_CD14.Mono.2"
# [13] "16_Pre.B"       "10_cDC"         "11_CD14.Mono.1" "25_NK"
# [17] "21_CD4.N2"      "22_CD4.M"       "23_CD8.EM"      "19_CD8.N"
# [21] "24_CD8.CM"      "26_Unk"         "20_CD4.N1"      "14_Unk"
# [25] "13_CD16.Mono"   "18_Plasma"

# %%
cnts <- assays(df)$counts

# %%
colnames(cnts) <- colData(df)$BioClassification

# %%
saveRDS(cnts, "/scratch/karius/reference/sc_rnaseq.sparse.rds")

# %%
write.table(cnts, "/scratch/karius/reference/sc_rnaseq.tsv")

# %%
aggregate(t(cnts), by=as.list(colnames(cnts)), FUN=sum)
# Out:
# Error in aggregate.data.frame(as.data.frame(x), ...): arguments must have same length
# Traceback:
#
# 1. aggregate(t(cnts), by = as.list(colnames(cnts)), FUN = sum)
# 2. aggregate(t(cnts), by = as.list(colnames(cnts)), FUN = sum)
# 3. aggregate.data.frame(as.data.frame(x), ...)
# 4. stop("arguments must have same length")

# %%
cnts[colData(df)$BioClassification == '05_CMP.LMPP', :]
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:54: unexpected ':'
# 1: cnts[colData(df)$BioClassification == '05_CMP.LMPP', :
#                                                          ^
# Traceback:

# %%
colnames(cnts)
# Out:
#     [1] "05_CMP.LMPP"    "08_GMP.Neut"    "01_HSC"         "06_CLP.1"
#     [5] "01_HSC"         "01_HSC"         "15_CLP.2"       "02_Early.Eryth"
#     [9] "02_Early.Eryth" "05_CMP.LMPP"    "05_CMP.LMPP"    "05_CMP.LMPP"
#    [13] "07_GMP"         "05_CMP.LMPP"    "05_CMP.LMPP"    "02_Early.Eryth"
#    [17] "02_Early.Eryth" "15_CLP.2"       "05_CMP.LMPP"    "01_HSC"
#    [21] "01_HSC"         "07_GMP"         "06_CLP.1"       "08_GMP.Neut"
#    [25] "01_HSC"         "07_GMP"         "01_HSC"         "06_CLP.1"
#    [29] "07_GMP"         "01_HSC"         "01_HSC"         "05_CMP.LMPP"
#    [33] "05_CMP.LMPP"    "01_HSC"         "05_CMP.LMPP"    "02_Early.Eryth"
#    [37] "15_CLP.2"       "01_HSC"         "01_HSC"         "05_CMP.LMPP"
#    [41] "09_pDC"         "01_HSC"         "01_HSC"         "05_CMP.LMPP"
#    [45] "09_pDC"         "02_Early.Eryth" "05_CMP.LMPP"    "07_GMP"
#    [49] "08_GMP.Neut"    "05_CMP.LMPP"    "01_HSC"         "05_CMP.LMPP"
# ...
