# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from fragments_h5.fragments_h5 import build_fragments_h5

if False:
    DATA_DIR = "/home/nboley/src/fragmentomics_tools/test/fragment_array/data/"
    bam_path =  os.path.join(DATA_DIR, "./small.chr6.bam")
    fasta_file_path = os.path.join(DATA_DIR, "./GRCh38.p12.genome.chr6_99110000_99130000.fa.gz")
    ofname = os.path.join(DATA_DIR, "small.chr6.bam.frag.h5")
    build_fragments_h5(
        bam_path, ofname, "test_sample", "hg38", fasta_file=fasta_file_path
    )

# %%
from fragmentomics_tools import RegionFragmentArray, Region
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from fragmentomics_tools import RegionFragmentArray, Region
#
# File ~/src/fragmentomics_tools/fragmentomics_tools/__init__.py:1
# ----> 1 from .fragment_array import FragmentArray, RegionFragmentArray, merge_fragment_arrays
#       2 from .region import Region
#       4 __all__ = [FragmentArray, RegionFragmentArray, merge_fragment_arrays, Region]
#
# File ~/src/fragmentomics_tools/fragmentomics_tools/fragment_array/__init__.py:1
# ----> 1 from .fragment_array import FragmentArray, RegionFragmentArray, merge_fragment_arrays
#       3 __all__ = [FragmentArray, RegionFragmentArray, merge_fragment_arrays]
#
# File ~/src/fragmentomics_tools/fragmentomics_tools/fragment_array/fragment_array.py:26
#      23 from .fragment_matrix import RegionFragmentMatrix, FragmentMatrix
#      24 from .fragment_matrix_math import reverse_sum_pool
# ---> 26 from fragmentomics_tools.plot.tracks import (
#      27     VectorTrack,
#      28     EmptyTrack,
#      29     VplotTrack,
#      30     VplotDensityTrack,
#      31     MotifTrack,
#      32     Line,
#      33     VLine,
#      34     Tracks,
#      35     MidpointCoverageTrack,
#      36     CoverageTrack,
#      37 )
#      40 DEFAULT_MIN_SCALING_FACTOR: float = 1e-6
#      41 DEFAULT_MAX_SCALING_FACTOR: float = 10.0
#
# File ~/src/fragmentomics_tools/fragmentomics_tools/plot/tracks.py:19
#      15 import copy
#      17 import pysam
# ---> 19 from fbio.formats import (
#      20     BigWigReader,
#      21     NarrowPeakBigBedReader,
#      22     BedIntervalTreeReader,
#      23     TabixBedReader,
#      24     GenePredReader,
#      25 )
#      26 from fragmentomics_tools.region import intervals_intersect
#      28 from fbio.util import aws_utils
#
# ModuleNotFoundError: No module named 'fbio'

# %%
rfa = RegionFragmentArray.from_fragments_h5("/home/nboley/src/fragmentomics_tools/test/fragment_array/data/small.chr6.bam.frag.h5", Region("chr6", 99110000, 99130000))

# %%
rfa.plot()
